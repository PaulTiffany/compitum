# %% [markdown]
# # Snippet from Home.md

# %%
# Compitum's interface is CLI-first. Install the package, then route a prompt
# and read its certificate straight from the command line.
# !pip install -e . -q
# !compitum route --prompt "Summarize the key differences between mitosis and meiosis for grade 9." --trace --verbose

# Constraints are linear bounds (A x <= b) over a small feature set (latency
# class, cost class, PII level, region), loaded from YAML -- see
# configs/constraints_us_default.yaml in the repo for the default, or pass
# your own with --constraints path/to/file.yaml.

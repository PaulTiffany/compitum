# %% [markdown]
# # Snippet from Control-of-Error-in-Practice.md

# %%
# In boundary.py - explicit uncertainty quantification
return {
    "winner": m1,
    "utility_gap": float(gap),
    "entropy": float(entropy),
    "uncertainty": sigma,
    "is_boundary": bool(is_boundary),
}

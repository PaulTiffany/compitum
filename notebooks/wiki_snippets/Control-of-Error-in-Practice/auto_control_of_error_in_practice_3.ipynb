# %% [markdown]
# # Snippet from Control-of-Error-in-Practice.md

# %%
# In constraints.py - feasibility as a pre-filter
viable = [m for m in models if self._is_feasible(m, xB, context)]
if not viable:
    return fallback_with_violations
# Only compute utilities for viable models

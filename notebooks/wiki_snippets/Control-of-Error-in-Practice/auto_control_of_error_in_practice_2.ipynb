# %% [markdown]
# # Snippet from Control-of-Error-in-Practice.md

# %%
# In cli.py - clean ablation flags
CompitumRouter(
    ...,
    enable_metric_update=not args.no_metric_update,
    enable_controller=not args.no_controller,
)

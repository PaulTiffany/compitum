# %% [markdown]
# # Snippet from Control-of-Error-in-Practice.md

# %%
# In boundary.py - only update on clear decisions
is_boundary = (
    (gap < threshold or entropy > threshold)
    and (sigma > threshold)
)
# Don't update metric on boundary cases - too noisy

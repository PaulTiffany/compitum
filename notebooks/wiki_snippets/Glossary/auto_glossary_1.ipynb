# %% [markdown]
# # Snippet from Glossary.md

# %%
\# Snippet: Compute Sample Free Energy

from compitum.energy import free\_energy

components = {'quality': 0.8, 'latency': 0.2, 'cost': 0.1, 'distance': 0.15, 'coherence': -0.05}

weights = {'alpha': 0.4, 'beta\_t': 0.2, 'beta\_c': 0.15, 'beta\_d': 0.15, 'beta\_s': 0.1}

E = free\_energy(components, weights)

print(f"E: {E:.3f}")  # Negative ideal; ties to shadow sensitivity.

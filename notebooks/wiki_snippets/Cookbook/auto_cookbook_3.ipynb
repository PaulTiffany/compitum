# %% [markdown]
# # Snippet from Cookbook.md

# %%
>>> route("What is machine learning?", trace=False)
Model: claude-sonnet-4.5
Utility: 8.3
Drift: -0.02
Entropy: 1.92
>>> set_constraint('latency', 1.0)
Updated latency = 1.0
>>> route("Explain quantum computing", trace=False)
Model: gpt-4o-mini
Utility: 7.1
Drift: -0.01
Entropy: 2.1
>>> cert = route("Solve x^2 - 4 = 0")
Certificate:
{
  "prompt": "Solve x^2 - 4 = 0",
  ...
}

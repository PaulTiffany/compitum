# %% [markdown]
# # Snippet from Cookbook.md -- verified real REPL transcript (see the REPL recipe notebook for the actual script)

# %%
"""Verified real transcript from the REPL recipe (piping two prompts then quit).
Real toy demo model names are `fast`, `thinking`, `auto` -- not `claude-sonnet-4.5`
or `gpt-4o-mini` (fictional). There is no `set_constraint()` helper, no
top-level `prompt` key on the certificate, and no bare "Certificate:" dump
with a `prompt` field -- see the real schema in the REPL recipe / Certificate-Schema."""

# $ python repl.py
# compitum REPL -- type a prompt and press Enter ('quit' to exit)
# > What is machine learning?
#   model=auto utility=-0.4295 gap=0.0183 entropy=1.0986 is_boundary=False
# > Explain quantum computing
#   model=auto utility=-0.4334 gap=0.0192 entropy=1.0986 is_boundary=False
# > quit

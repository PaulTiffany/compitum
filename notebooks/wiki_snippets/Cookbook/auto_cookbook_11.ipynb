# %% [markdown]
# # Snippet from Cookbook.md

# %%
"""Illustrative memory-profiling sketch. `memory_profiler` is a third-party
tool, not a declared project dependency (`pip install memory_profiler` first).
There is no bundled memory-profiling script in this repo -- this reuses the
same real CompitumRouter construction as the REPL/batch recipes."""
from memory_profiler import profile
from batch_convergence import build_router  # reuse the REPL/batch recipe's builder


@profile
def memory_test():
    router = build_router()
    for i in range(50):
        router.route(f"Test prompt {i}")


if __name__ == "__main__":
    memory_test()

# %% [markdown]
# # Minimal Routing Demo
#
# This demo notebook shows a minimal import and placeholder for routing.
# It avoids heavy dependencies and does not require RouterBench.

# %%
import compitum
print('Compitum version:', getattr(compitum, '__version__', 'unknown'))
print('Available modules:', compitum.__all__)

# %% [markdown]
# ## Outline for a simple router (placeholder)
# The full router requires models, predictors, constraints, metric, energy, etc.
# Use `examples/` for executable scripts. This notebook demonstrates imports and can be extended.

# %% [markdown]
# # Getting Started with Compitum
#
# This notebook helps you verify your environment and shows a minimal import of the Compitum package.
#
# - Repository: https://github.com/PaulTiffany/compitum
# - Wiki: https://github.com/PaulTiffany/compitum/wiki

# %% [markdown]
# ## Environment Setup
#
# From the repository root, install Jupyter and Compitum in editable mode (once per environment):
#
# ```bash
# # Windows (PowerShell)
# python -m venv .venv
# .venv\\Scripts\\Activate.ps1
# pip install --upgrade pip
# pip install jupyter
# pip install -e .
# python -m ipykernel install --user --name compitum-venv --display-name "Python (compitum)"
# jupyter notebook
# ```
#
# After activation, select the "Python (compitum)" kernel for this notebook.

# %%
# Python and pip versions
import sys, subprocess
print(sys.version)
subprocess.run([sys.executable, '-m', 'pip', '--version'], check=False)

# %%
# Minimal Compitum import and version check
import compitum
print('Compitum version:', getattr(compitum, '__version__', 'unknown'))
print('Compitum modules:', compitum.__all__)

# %% [markdown]
# ## Next Steps
#
# - Explore API docs in `src/compitum/`.
# - Check `examples/` for scripts that use the router and metrics.
# - See the Wiki for walkthroughs and deeper explanations.

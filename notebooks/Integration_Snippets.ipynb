# %% [markdown]
# # Integration Snippets (lightweight)
#
# This notebook provides safe, minimal code snippets mirroring the Integration Guide.
# Use these snippets as reference; full integrations may require optional extras not installed in CI.

# %%
# Import the package and list key modules
import compitum
print('Compitum version:', getattr(compitum, '__version__', 'unknown'))
print('Modules:', sorted(compitum.__all__))

# %% [markdown]
# ## Example scaffold (pseudo)
# Below is a reference scaffold for programmatic routing in your app.
# Adjust imports to your needs; see `examples/` for runnable scripts.

# %%
snippet = '''
# from compitum.router import CompitumRouter
# router = CompitumRouter(...)
# cert = router.route("Prove binomial identity...")
# print(cert.to_json())
'''
print(snippet)

# %% [markdown]
# # Constraints and Certificates (overview)
#
# This notebook gives a high-level view of compitum's certificate structure without running heavy evaluations.

# %%
from compitum.router import SwitchCertificate
example = SwitchCertificate(
    model='example-model',
    utility=0.0,
    utility_components={'distance': 0.0},
    constraints={'feasible': True},
    boundary_analysis={'margin': 0.0},
    drift_status={'trust_radius': 1.0},
    pgd_signature='deadbeef',
    timestamp=0.0,
)
print(example.to_json())

# %% [markdown]
# For full evaluation flows, see `tools/ci_orchestrator.py` and RouterBench-clean configs under `data/rb_clean`.
# In CI, heavy steps are gated and won't run unless explicitly enabled.
